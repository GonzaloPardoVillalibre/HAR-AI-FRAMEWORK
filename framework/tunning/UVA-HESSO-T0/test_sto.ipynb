# %%
import pandas as pd
import os

# %%
def expandcolumn(df,imu):
    dfquat = df[imu].str.split(',',4,expand=True)
    dfquat.columns=[imu+"_w",imu+"_x",imu+"_y",imu+"_z"]
    return dfquat

# %%
input_folder = 'original-dataset'
file = 'S01_A05_T02.sto'
activity = 'A05'
dfraw= pd.read_csv(os.path.join('.',input_folder,activity,file),sep='\t',skiprows=5)
dfraw.head()
#REMOVE FIRST LINES OF QUATS (CALIBRATION ORIENTATION where timestamp == 0)
dfraw = dfraw[dfraw.time > 0]
#REMOVE TIME
dfraw.pop('time')
dfraw.head()
# Out:
#                                            torso_imu  \
# 1  0.6014272903824657,0.22211007847347125,-0.6932...
# 2  0.6014272903824657,0.22211007847347125,-0.6932...
# 3  0.6014911160418236,0.22209671965567584,-0.6931...
# 4  0.6014911160418236,0.22209671965567584,-0.6931...
# 5  0.6014911160418236,0.22209671965567584,-0.6931...
#
#                                        humerus_r_imu  \
# 1  0.04940292943355372,0.6191367127998604,-0.1550...
# 2  0.04939913404077033,0.6190891474623667,-0.1549...
# 3  0.049396864386569955,0.6189607096211903,-0.155...
# 4  0.049396864386569955,0.6189607096211903,-0.155...
# 5  0.049396864386569955,0.6189607096211903,-0.155...
#
#                                         radius_r_imu  \
# 1  0.5315862985397305,-0.1822953013991589,0.10169...
# 2  0.5315851636651202,-0.18219491501088206,0.1018...
# 3  0.5315851636651202,-0.18219491501088206,0.1018...
# 4  0.5315948462129488,-0.1820982345661738,0.10189...
# 5  0.5315948462129488,-0.1820982345661738,0.10189...
#
#                                        humerus_l_imu  \
# 1  0.6567030405421166,-0.0790003657725403,-0.6386...
# 2  0.6568276760172058,-0.07900332887539473,-0.638...
# 3  0.6568276760172058,-0.07900332887539473,-0.638...
# 4  0.6568276760172058,-0.07900332887539473,-0.638...
# 5  0.656884530551456,-0.0789981396157178,-0.63848...
#
#                                         radius_l_imu
# 1  0.34119180296539947,0.08659791950997536,-0.419...
# 2  0.34118884671889815,0.08669716591596854,-0.419...
# 3  0.34120316126193373,0.0867008032866637,-0.4195...
# 4  0.34120316126193373,0.0867008032866637,-0.4195...
# 5  0.34121747419429166,0.08670444024808056,-0.419...

# %%
imus = dfraw.columns.to_list()
print(imus)
# Out:
# ['torso_imu', 'humerus_r_imu', 'radius_r_imu', 'humerus_l_imu', 'radius_l_imu']

# %%
dflist = []
for imu in imus:
    dfquat = expandcolumn(dfraw,imu)
    dflist.append(dfquat)
    #print(dfquat.head())
dfconcat = dflist[0]
for i,df in enumerate(dflist):
    if i>0:
        dfconcat=pd.concat([dfconcat,df],axis=1)
dfconcat.head()
# Out:
