# %% [markdown]
# ## Examine IMU information

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from AuxFunctions import generate_df
from AuxFunctions import plot_measurements

# %%
InputFilesList = ['Pelvis.csv', 'R_UpLeg.csv', 'R_LowLeg.csv', 'R_LowLeg2.csv', 'R_Foot.csv',
                                'L_UpLeg.csv', 'L_LowLeg.csv', 'L_LowLeg2.csv', 'L_Foot.csv']
boneNamesList = ['PELV',  'RUL', 'RLL', 'RLL2', 'RF',
                           'LUL', 'LLL', 'LLL2', 'LF']

# %% [markdown]
# # Activities
# - S01-Trial-FigureofEight-1-
# - S01-Trial-FigureofEight-2-
# - S01-Trial-Fivemin-1-
# - S01-Trial-Fivemin-2-
# - S01-Trial-HighKneeJog-1-
# - S01-Trial-HighKneeJog-2-
# - S01-Trial-Jog-1-
# - S01-Trial-Jog-2-
# - S01-Trial-JumpingJacks-1-
# - S01-Trial-JumpingJacks-2-
# - S01-Trial-SpeedSkater-1-
# - S01-Trial-SpeedSkater-2-
# - S01-Trial-Static-1-
# - S01-Trial-TUG-1-
# - S01-Trial-Walk-1-
# - S01-Trial-Walk-2-
# - S01-Trial-Zigzag-1-
# - S01-Trial-Zigzag-2-

# %%
filename = 'S01-Trial-Walk-1-' + InputFilesList[1] 
bonename = boneNamesList[2]

# %%
df1 = generate_df(filename,bonename)
df1.head(10)
# Out:
# 4 bone     ori_1     ori_2      ori_3     ori_4     acc_1     acc_2     acc_3  \
# 0  RLL  0.562746  0.407142  -0.319867   0.64439   5.58062  0.904634  1.696066
# 1  RLL  0.561899  0.407818  -0.318733  0.645263  5.054805    1.0475  1.789496
# 2  RLL  0.560961  0.409281  -0.317552  0.645734  4.802176  0.952564  2.057735
# 3  RLL  0.559827  0.411605  -0.316567  0.645725  5.142205  0.763705  2.462409
# 4  RLL  0.558351  0.414765  -0.315684  0.645413  5.537594  0.770982  2.982585
# 5  RLL  0.556535  0.418616  -0.314932  0.644862  5.971802  0.911781  3.812431
# 6  RLL  0.554482  0.422821  -0.314386  0.644153  6.840259  0.600915   4.60991
# 7  RLL   0.55227  0.427059  -0.313639  0.643622  7.664709  0.487139  5.593824
# 8  RLL  0.549913  0.431156  -0.312537  0.643444   8.33833  0.706415  6.677532
# 9  RLL  0.548066  0.434386  -0.311134  0.643528  8.891974  1.221387  7.893385
#
# 4     gyr_1      gyr_2      gyr_3     mag_1      mag_2     mag_3
# ...

# %%
plot_measurements(df1,bonename)
